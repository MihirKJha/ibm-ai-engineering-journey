# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Multiple Linear Regression</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to make the prediction for multiple inputs.</li><li> How to use linear class to build more complex models.</li><li> How to build a custom module.</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will review how to make a prediction in several different ways by using PyTorch.</p>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size="3">
#         1. <a href="#Prediction">Prediction</a><br>
#         2. <a href="#Class-Linear">Class Linear</a><br>
#         3. <a href="#Build-Custom-Modules">Build Custom Modules</a>
#
# <p>Estimated Time Needed: <strong>15 min</strong></p>
# </font>
# </div>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# Import the libraries and set the random seed.

# %%
# %%time
# %pip install numpy matplotlib
# %pip install torch torchvision torchaudio torchtext
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (2.4.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.11.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.12/site-packages (0.26.0)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.12/site-packages (2.11.0)
# Requirement already satisfied: torchtext in /opt/conda/lib/python3.12/site-packages (0.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools<82 in /opt/conda/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.12/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /opt/conda/lib/python3.12/site-packages (from torch) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /opt/conda/lib/python3.12/site-packages (from torch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /opt/conda/lib/python3.12/site-packages (from torch) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /opt/conda/lib/python3.12/site-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/conda/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /opt/conda/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /opt/conda/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/conda/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->torchtext) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->torchtext) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->torchtext) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# CPU times: user 32.5 ms, sys: 23.8 ms, total: 56.3 ms
# Wall time: 2.88 s

# %%
# Import the libraries and set the random seed

from torch import nn
import torch
torch.manual_seed(1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Prediction">Prediction</h2>

# %% [markdown]
# Set weight and bias.

# %%
# Set the weight and bias

w = torch.tensor([[2.0], [3.0]], requires_grad=True)
b = torch.tensor([[1.0]], requires_grad=True)

w
b
# Out:
# tensor([[1.]], requires_grad=True)

# %% [markdown]
# Define the parameters. <code>torch.mm</code> uses matrix multiplication instead of scaler multiplication.

# %%
# Define Prediction Function

def forward(x):
    yhat = torch.mm(x, w) + b
    return yhat

# %% [markdown]
# The function <code>forward</code> implements the following equation:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.6.1_matrix_eq.png" width="600" alt="Matrix Linear Regression">

# %% [markdown]
# If we input a <i>1x2</i> tensor, because we have a <i>2x1</i> tensor as <code>w</code>, we will get a <i>1x1</i> tensor:

# %%
# Calculate yhat

x = torch.tensor([[1.0, 2.0]])
yhat = forward(x)
print("The result: ", yhat)
# Out:
# The result:  tensor([[9.]], grad_fn=<AddBackward0>)

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/JBkvPoMCCa-PDXCF_4aQfQ/image%20-1-.png" width="300" alt="Linear Regression Matrix Sample One">

# %% [markdown]
# # Each row of the following tensor represents a sample:

# %%
# Sample tensor X

X = torch.tensor([[1.0, 1.0], [1.0, 2.0], [1.0, 3.0]])

# %%
# Make the prediction of X 

yhat = forward(X)
print("The result: ", yhat)
# Out:
# The result:  tensor([[ 6.],
#         [ 9.],
#         [12.]], grad_fn=<AddBackward0>)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# ## Class Linear

# %% [markdown]
# We can use the linear class to make a prediction. You'll also use the linear class to build more complex models.

# %% [markdown]
# Let us create a model.

# %%
# Make a linear regression model using build-in function

model = nn.Linear(2, 1)

# %% [markdown]
# Make a prediction with the first sample:

# %%
# Make a prediction of x

yhat = model(x)
print("The result: ", yhat)
# Out:
# The result:  tensor([[-0.3969]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Predict with multiple samples <code>X</code>:

# %%
# Make a prediction of X

yhat = model(X)
print("The result: ", yhat)
# Out:
# The result:  tensor([[-0.0848],
#         [-0.3969],
#         [-0.7090]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# The function performs matrix multiplication as shown in this image:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.6.1multi_sample_example.png" width="600" alt="Linear Regression Matrix Sample One">

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# ## Build Custom Modules

# %% [markdown]
# Now, you'll build a custom module. You can make more complex models by using this method later.

# %%
# Create linear_regression Class

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Build a linear regression object. The input feature size is two.

# %%
model = linear_regression(2, 1)

# %% [markdown]
# This will input the following equation:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.6.1_matrix_eq.png" width="600" alt="Matrix Linear Regression">

# %% [markdown]
# You can see the randomly initialized parameters by using the <code>parameters()</code> method:

# %%
# Print model parameters

print("The parameters: ", list(model.parameters()))
# Out:
# The parameters:  [Parameter containing:
# tensor([[ 0.3319, -0.6657]], requires_grad=True), Parameter containing:
# tensor([0.4241], requires_grad=True)]

# %% [markdown]
# You can also see the parameters by using the <code>state_dict()</code> method:

# %%
# Print model parameters

print("The parameters: ", model.state_dict())
# Out:
# The parameters:  OrderedDict({'linear.weight': tensor([[ 0.3319, -0.6657]]), 'linear.bias': tensor([0.4241])})

# %% [markdown]
# Now we input a 1x2 tensor, and we will get a 1x1 tensor.

# %%
# Make a prediction of x

yhat = model(x)
print("The result: ", yhat)

# %% [markdown]
# The shape of the output is shown in the following image:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.6.1_matrix_eq.png" width="600" alt="Matrix Linear Regression">

# %% [markdown]
# Make a prediction for multiple samples:

# %%
# Make a prediction of X

yhat = model(X)
print("The result: ", yhat)

# %% [markdown]
# The shape is shown in the following image:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter2/2.6.1Multi_sample.png" width="600" alt="Multiple Samples Linear Regression">

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Build a model or object of type <code>linear_regression</code>. Using the <code>linear_regression</code> object will predict the following tensor:

# %%
# Practice: Build a model to predict the follow tensor.

X = torch.tensor([[11.0, 12.0, 13, 14], [11, 12, 13, 14]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!-- Your answer is below:
# model = linear_regression(4, 1)
# yhat = model(X)
# print("The result: ", yhat)
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a/">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
